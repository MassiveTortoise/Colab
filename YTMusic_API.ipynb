# %% [markdown]
# <a href="https://colab.research.google.com/github/MassiveTortoise/Colab/blob/Colab/YTMusic_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ytmusicapi

# %%
from ytmusicapi import YTMusic

yt = YTMusic('oauth.json')
playlistId = yt.create_playlist('test', 'test description')
search_results = yt.search('Oasis Wonderwall')
yt.add_playlist_items(playlistId, [search_results[0]['videoId']])
# Out:
# {'status': 'STATUS_SUCCEEDED',
#  'playlistEditResults': [{'videoId': '6hzrDeceEKc',
#    'setVideoId': '56B44F6D10557CC6',
#    'multiSelectData': {'multiSelectParams': 'CAISIlBMZUJoS3JNLWN0cTF5bDNYejVqTEpxZGR4ZmhtbFB3bHk=',
#     'multiSelectItem': 'Ch8KCzZoenJEZWNlRUtjEhA1NkI0NEY2RDEwNTU3Q0M2'}}]}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

search_results = yt.search('Hello')
df = pd.DataFrame(search_results)
df.head()
# Out:
#             category resultType      videoId             videoType  \
# 0         Top result      video  YQHsXMglC9A  MUSIC_VIDEO_TYPE_OMV
# 1  More from YouTube       song  gfc3YircI-g  MUSIC_VIDEO_TYPE_ATV
# 2  More from YouTube       song  3qbyBtoaS7w  MUSIC_VIDEO_TYPE_ATV
# 3  More from YouTube       song  PwIgMkhE3rQ  MUSIC_VIDEO_TYPE_ATV
# 4              Songs       song  yjo_aXygRDI  MUSIC_VIDEO_TYPE_ATV
#
#                           title  \
# 0  Hello (Official Music Video)
# 1                         Hello
# 2          Hello (Reggae Cover)
# 3                         Hello
# 4                         Hello
#
#                                              artists views duration  \
# 0  [{'name': 'Adele', 'id': 'UCRw0x9_EfawqmgDI2Ig...  3.1B     6:07
# 1  [{'name': 'Fame on Fire', 'id': 'UCXrWV884xU7T...   NaN     5:01
# 2  [{'name': 'Conkarah', 'id': 'UCdCVx1CEhuEGEqzr...   NaN     3:59
# 3  [{'name': 'Anth', 'id': 'UCzNeZtSZITtxhVZrCFae...   NaN     2:38
# ...

# %% [markdown]
# # Hypotheses
#
# 1.   Hypothesis: Songs categorized as "Official Music Video" have a higher average number of views than songs categorized as "Live Performance."
#
# 2.   Hypothesis: The average duration of songs has decreased over time (as represented by the year feature).
#
# 3.   Hypothesis: There is a relationship between the category of a song (e.g., "Song", "Video") and the average duration_seconds of the song.
#
# 4.   Hypothesis: There is a positive correlation between the number of artists featured on a song and the number of views it receives.
#
# 5.   Hypothesis: Albums (album feature) released more recently (higher year) have a higher average number of views per song.
