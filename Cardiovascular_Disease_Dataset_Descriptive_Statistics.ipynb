# %% [markdown]
# <a href="https://colab.research.google.com/github/Mimikhh/Colab/blob/Colab/Cardiovascular_Disease_Dataset_Descriptive_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the library you needs
import numpy as np
import pandas as pd

# Load the Cardiovascular Disease Dataset
mydata = pd.read_csv('Cardiovascular_Disease_Dataset.csv')

# %%
# Display the first five rows of the data
mydata.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
# Five point summary of the data
mydata.describe().T
# Out:
#                     count          mean           std       min         25%  \
# patientid          1000.0  5.048704e+06  2.895905e+06  103368.0  2536439.50
# age                1000.0  4.924200e+01  1.786473e+01      20.0       34.00
# gender             1000.0  7.650000e-01  4.242110e-01       0.0        1.00
# chestpain          1000.0  9.800000e-01  9.531571e-01       0.0        0.00
# restingBP          1000.0  1.517470e+02  2.996523e+01      94.0      129.00
# serumcholestrol    1000.0  3.114470e+02  1.324438e+02       0.0      235.75
# fastingbloodsugar  1000.0  2.960000e-01  4.567194e-01       0.0        0.00
# restingrelectro    1000.0  7.480000e-01  7.701228e-01       0.0        0.00
# maxheartrate       1000.0  1.454770e+02  3.419027e+01      71.0      119.75
# exerciseangia      1000.0  4.980000e-01  5.002462e-01       0.0        0.00
# oldpeak            1000.0  2.707700e+00  1.720753e+00       0.0        1.30
# ...

# %%
# Info about the data
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patientid          1000 non-null   int64
#  1   age                1000 non-null   int64
#  2   gender             1000 non-null   int64
#  3   chestpain          1000 non-null   int64
#  4   restingBP          1000 non-null   int64
#  5   serumcholestrol    1000 non-null   int64
#  6   fastingbloodsugar  1000 non-null   int64
#  7   restingrelectro    1000 non-null   int64
#  8   maxheartrate       1000 non-null   int64
#  9   exerciseangia      1000 non-null   int64
#  10  oldpeak            1000 non-null   float64
#  11  slope              1000 non-null   int64
#  12  noofmajorvessels   1000 non-null   int64
#  13  target             1000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 109.5 KB

# %%
# Shape of the data
mydata.shape
# Out:
# (1000, 14)

# %%
# Checking for the null values
mydata.isna().any()
# Out:
# patientid            False
# age                  False
# gender               False
# chestpain            False
# restingBP            False
# serumcholestrol      False
# fastingbloodsugar    False
# restingrelectro      False
# maxheartrate         False
# exerciseangia        False
# oldpeak              False
# slope                False
# noofmajorvessels     False
# target               False
# dtype: bool

# %%
# What is the age range of patients in the dataset?
age_range = f"Age Range: {mydata['age'].min()} - {mydata['age'].max()}"
age_range
# Out:
# 'Age Range: 20 - 80'

# %%
# How many males and females are represented in the dataset?
gender_count = mydata['gender'].value_counts()
gender_count
# Out:
# gender
# 1    765
# 0    235
# Name: count, dtype: int64

# %%
# What is the most common type of chest pain observed in the patients?
import seaborn as sns
sns.countplot(x="chestpain", hue="gender", data=mydata)
# Out:
# <Axes: xlabel='chestpain', ylabel='count'>

# %%
# What is the average resting blood pressure among the patients?
mydata["restingBP"].mean()
# Out:
# 151.747

# %%
# How does serum cholesterol vary across different patients?
mydata['serumcholestrol'].describe()
# Out:
# count    1000.000000
# mean      311.447000
# std       132.443801
# min         0.000000
# 25%       235.750000
# 50%       318.000000
# 75%       404.250000
# max       602.000000
# Name: serumcholestrol, dtype: float64

# %%
# What are the predominant resting electrocardiogram results in the dataset?
angina_count = mydata['restingBP'].value_counts()
angina_count
# Out:
# restingBP
# 127    26
# 130    25
# 143    23
# 126    23
# 125    22
#        ..
# 188     4
# 95      3
# 148     3
# 179     3
# 146     2
# Name: count, Length: 95, dtype: int64

# %%
# How many patients experienced exercise-induced angina?
angina_count = mydata['exerciseangia'].value_counts()
angina_count
# Out:
# exerciseangia
# 0    502
# 1    498
# Name: count, dtype: int64

# %%
# What is the average oldpeak (ST depression induced by exercise relative to rest) among the patients?
mydata["oldpeak"].mean()
# Out:
# 2.7077

# %%
# What percentage of patients in the dataset have heart disease (target = 1)?
print(f"{mydata['target'].mean() * 100:.2f}%")
# Out:
# 58.00%

# %%
# Can you identify the patient with the highest age in the dataset?
mydata["age"].max()
# Out:
# 80

# %%
# Who is the patient with the lowest resting blood pressure?
mydata.loc[mydata['restingBP'] == mydata['restingBP'].min()]
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 1       119250   40       1          0         94              229
# 205    2080399   34       1          2         94              254
# 299    2956524   70       1          0         94              258
# 506    4994167   35       0          2         94              368
# 753    7712383   68       0          0         94              269
# 770    7905830   27       1          2         94              174
# 893    8976590   47       0          0         94              433
# 975    9718692   64       0          0         94              428
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 1                    0                1           115              0      3.7
# 205                  0                1           196              1      3.7
# 299                  0                1           129              0      0.1
# ...

# %%
# Is there a relationship between chest pain type and the presence of heart disease?
mydata.chestpain.corr(mydata.target)

#correlation of chestpain and target
# Out:
# 0.5542280802925407

# %%
# How many patients have all three major vessels showing defects?
mydata.loc[mydata['noofmajorvessels'] == 3].count()
# Out:
# patientid                              116
# age                                    116
# gender                                 116
# chestpain                              116
# restingBP                              116
# serumcholestrol                        116
# fastingbloodsugar                      116
# restingrelectro                        116
# maxheartrate                           116
# exerciseangia                          116
# oldpeak                                116
# slope                                  116
# noofmajorvessels                       116
# target                                 116
# Sum of patiens with 3 major vessels      0
# dtype: int64

# %%
# Write down your Summary, Observations, and Conclusion

# %% [markdown]
# # Summary

# %% [markdown]
# This dataset provides information about patients and their risk of heart disease. It includes features such as age, gender, chest pain type, resting blood pressure, cholesterol levels, and more. The goal is to analyze this data to understand the factors that contribute to heart disease and potentially predict the likelihood of heart disease in individuals.

# %% [markdown]
# # Observations:

# %% [markdown]
# *   The dataset contains information for 1000 patients
# *   The age range of patients is from 20 to 80 years.
# *   There are 765 males and 235 females in the dataset.
# *   There appears to be a relationship between chest pain type and the presence of heart disease, with certain types of chest pain being more common in patients with heart disease.
# *   58% of patients have heart disease.

# %% [markdown]
# # Conclusion

# %% [markdown]
# By analyzing the provided dataset, we gain insights into various patient characteristics and their potential correlation with heart disease. Further analysis, including statistical modeling and machine learning techniques, could help in developing predictive models for heart disease risk assessment.
